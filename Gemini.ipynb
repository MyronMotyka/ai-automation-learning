# %% [markdown]
# <a href="https://colab.research.google.com/github/MyronMotyka/ai-automation-learning/blob/main/Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-genai

# %%
from google import genai
from getpass import getpass

api_key = getpass("Enter your Gemini API key: ")

client = genai.Client(api_key=api_key)
# Out:
# Enter your Gemini API key: ··········

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Say hello in one short sentence."
)

print(response.text)
# Out:
# Hello, it's great to meet you!

# %%
def ask_ai(text):
    response = client.models.generate_content(
        model="gemini-3.6-flash",
        contents=text
    )

    return response.text

# %%
answer = ask_ai("Explain what an API is in one short sentence.")

print(answer)
# Out:
# An API is a software messenger that allows different applications to communicate and share data with each other.

# %%
services = [
    "Furniture Assembly",
    "TV Mounting",
    "Baseboard Installation",
    "Drywall Repair"
]

print(services)
# Out:
# ['Furniture Assembly', 'TV Mounting', 'Baseboard Installation', 'Drywall Repair']

# %%
for service in services:
    print(service)
# Out:
# Furniture Assembly
# TV Mounting
# Baseboard Installation
# Drywall Repair

# %%
for service in services:
    prompt = f"Explain this handyman service in one short sentence: {service}"

    answer = ask_ai(prompt)

    print("SERVICE:", service)
    print("ANSWER:", answer)
    print("--------------------")
# Out:
# SERVICE: Furniture Assembly
# ANSWER: We professionally put together your flat-pack or boxed furniture, saving you time and hassle.
# --------------------
# SERVICE: TV Mounting
# ANSWER: TV mounting safely secures your television to a wall using proper brackets and neatly manages all connected cables.
# --------------------
# SERVICE: Baseboard Installation
# ANSWER: Baseboard installation is the precise cutting and mounting of decorative trim along the bottom of your walls to protect them and give your room a polished, finished look.
# --------------------
# SERVICE: Drywall Repair
# ANSWER: Drywall repair fixes holes, cracks, and wall damage to restore a smooth, paint-ready surface.
# --------------------

# %%
results = {}

for service in services:
    prompt = f"Explain this handyman service in one short sentence: {service}"

    answer = ask_ai(prompt)

    results[service] = answer

print(results)
# Out:
# {'Furniture Assembly': 'Professional building and setup of flat-pack, boxed, and store-bought furniture for your home or office.', 'TV Mounting': 'TV mounting is a service that safely and securely installs your television onto a wall for an optimal viewing experience.', 'Baseboard Installation': 'Baseboard installation involves measuring, cutting, and securing decorative trim along the bottom of interior walls to create a polished, seamless transition between the wall and floor.', 'Drywall Repair': 'Fixing holes, cracks, and damage in walls and ceilings to restore a smooth, seamless surface.'}

# %%
print(results["TV Mounting"])
# Out:
# TV mounting is a service that safely and securely installs your television onto a wall for an optimal viewing experience.
